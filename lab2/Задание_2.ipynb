# %% [markdown]
# <a href="https://colab.research.google.com/github/V9502996099/ML/blob/main/lab2/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Введение в описательную статистику

# %% [markdown]
# 1. Выберите категориальную целевую переменную (**Y**)
#
# 2. Выберите переменную для анализа относительно категории (**X**)
#
# 3. Выведитие обобщенную статистическую информацию переменной (**X**)
#
# 2. Вычислите среднее, медиану, моду, минимум, максимум, стандартное отклонение относительно целевой пременной из файла Classification datasets в соответствии с вашим вариантом
#
# 3. Сделайте вывод относительно полученных результатов
#
# p.s если у вас нет категориальных признаков - преобразуйте любой числовой в категориальный (https://pandas.pydata.org/docs/reference/api/pandas.cut.html). Важно **не** использовать преобразованный Y вместе с этим же X (то есть, если вы преобразовали возраст в категорию, то вы не моежет использовать возраст в качестве X и возраст категорию в качестве Y)

# %%
df = pd.read_csv("/content/loan_approval_dataset.csv") # чтение файла
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
de = df.columns
print(de)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %% [markdown]
# Y = loan_status; X = income_annum

# %%
describe =  df[" loan_status"].describe()# ваш код здесь
describe
# Out:
# count          4269
# unique            2
# top        Approved
# freq           2656
# Name:  loan_status, dtype: object

# %%
mean = df.groupby(by=[" loan_status"])[" income_annum"].mean()# (среднее) ваш код здесь
mean
# Out:
#  loan_status
#  Approved    5.025904e+06
#  Rejected    5.113825e+06
# Name:  income_annum, dtype: float64

# %%
median = df.groupby(by=[" loan_status"])[" income_annum"].median()# (медиана) ваш код здесь
median
# Out:
#  loan_status
#  Approved    5000000.0
#  Rejected    5100000.0
# Name:  income_annum, dtype: float64

# %%
mode = df.groupby(by=[" loan_status"])[" income_annum"].apply(lambda x : x.mode()).reset_index(level=0) # (мода) ваш код здесь
mode.columns = [' loan_status', 'Mode']
mode
# Out:
#    loan_status     Mode
# 0     Approved  7000000
# 0     Rejected  4100000

# %%
median = df.groupby(by=[" loan_status"])[" income_annum"].median()# (медиана) ваш код здесь
median
# Out:
#  loan_status
#  Approved    5000000.0
#  Rejected    5100000.0
# Name:  income_annum, dtype: float64

# %%
median = df.groupby(by=[" loan_status"])[" income_annum"].median()# (медиана) ваш код здесь
median
# Out:
#  loan_status
#  Approved    5000000.0
#  Rejected    5100000.0
# Name:  income_annum, dtype: float64

# %%
min = df.groupby(by=[" loan_status"])[" income_annum"].min()# (минимум) ваш код здесь
min
# Out:
#  loan_status
#  Approved    200000
#  Rejected    200000
# Name:  income_annum, dtype: int64

# %%
max = df.groupby(by=[" loan_status"])[" income_annum"].max()# (максимум) ваш код здесь
max
# Out:
#  loan_status
#  Approved    9900000
#  Rejected    9900000
# Name:  income_annum, dtype: int64

# %%
std = df.groupby(by=[" loan_status"])[" income_annum"].std()# (стандартное отклонение) Ваш код здесь
std
# Out:
#  loan_status
#  Approved    2.827228e+06
#  Rejected    2.772946e+06
# Name:  income_annum, dtype: float64

# %% [markdown]
# Вычислите следующие квантили: 25%, 50% (медиана), 75% для числового признака вашего датасета. Затем найдите интерквартильный размах.

# %%
q1 = df[" income_annum"].quantile(0.25)# (25% квантиль) ваш код здесь
q1
# Out:
# 2700000.0

# %%
q2 = df[" income_annum"].quantile(0.5)# (50% квантиль) ваш код здесь
q2
# Out:
# 5100000.0

# %%
q3 = df[" income_annum"].quantile(0.75)# (75% квантиль) ваш код здесь
q3
# Out:
# 7500000.0

# %%
iqr = q3 - q1# (интерквартильный размах) ваш код здесь
iqr
# Out:
# 4800000.0

# %% [markdown]
# Какие выводы можно сделать исходя из полученных статистических данных?

# %% [markdown]
# **Ответ здесь**
#
# ```
# Отклоненные заявки имеют чуть более высокий средний годовой доход, чем утвержденные заявки. Это означает что годовой доход не самый важный фактор при выдаче кредита, ведь если бы это было так то в отклонённых заявках среднее значение было бы намного меньше, чем в утверждённых.
#
# В обеих категориях минимальный и максимальный годовой доход одинаков, что может означать, что в обеих группах есть заявители с самыми низкими и самыми высокими доходами.
#
# Различие между средним значением и медианой годового дохода может указывать на наличие заявок с очень высокими годовыми доходами, которые существенно влияют на среднее значение.
#
# Таким образом, мы понимаем, что средний годовой доход существенно не влияет на одобрение кредита.
#
# ```

# %% [markdown]
# ##Основы визуализации

# %% [markdown]
#  Постройте гистограмму переменной (X) относительно категориального признака (Y) из своего датасета.

# %%
sns.histplot(data=df, x=' income_annum', hue=' loan_status')
# Out:
# <Axes: xlabel=' income_annum', ylabel='Count'>

# %% [markdown]
# Постройте boxplot любого признака из своего датасета.
#
# 1) boxplot числовой переменной;
#
# 2) boxplot числовой переменной относительно категориальный переменной;
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.boxplot(df[" loan_term"])
plt.title("Boxplot кредитного срока")
plt.xlabel("Кредитный срок")
# Out:
# Text(0.5, 0, 'Кредитный срок')

# %%
sns.boxplot(x=df[" loan_term"], y=df[" loan_status"])
# Out:
# <Axes: xlabel=' loan_term', ylabel=' loan_status'>

# %% [markdown]
# Постройте диаграмму рассеивания для числовых признаков вашего датасета.
#
# *p.s. Если у вас только один числовой признак, преобразуйте категориальный при помощи LabelEncoder (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)*

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x=' commercial_assets_value', y=' bank_asset_value', data = df)
plt.title('Диаграмма рассеивания')
plt.xlabel('Стоимость комерческих активов')
plt.ylabel('Стоимость активов банка')
# Out:
# Text(0, 0.5, 'Стоимость активов банка')

# %% [markdown]
# Постройте матрицу корреляции для двух числовых признаков вашего датасета.

# %%
selected_features = [" income_annum", " loan_term"]
df_selected = df[selected_features]
corr_matrix = df_selected.corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Какие выводы можно сделать на основе графиков и матрицы корреляции?

# %% [markdown]
# **Ответ здесь**
# Стоимость коммерческиз активов не связа со стоимостью активов банка.
#
# Слабая зависисмость между кредытным сроком и годовым доходом.

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать следующие методы поиска выбросов:
# 1. На основе среднего и отклонения
# 2. Критерий Шовене
# 3. С помощью квартилей
# 4. Поиск выбросов по двум переменным
#
# [Посмотреть](http://course.omgtu.ru/wp-content/uploads/2021/04/3_%D0%92%D1%8B%D0%B1%D1%80%D0%BE%D1%81%D1%8B.pdf)
#
# P.S. в качестве возвразаемого значения методов может быть:
# 1. очищенный датафрейм
# 2. индексы выбросов ```df.series.index```

# %%
"""

Ваш код здесь

"""

# %% [markdown]
# ### Пример реализации одного метода

# %%
from statistics import median, mean

class Outline:
  def __init__(self, df):
    self.df = df

  def delete_outline_by_mean(self, column_name):
    mean_data = mean(self.df[column_name])
    maximum = mean_data * 2
    result = []

    for item in self.df[column_name]:
      if abs(item - mean_data) < maximum:
        result.append(item)

    return result

# %%
data = pd.DataFrame(
    data = {
        "col1": [1, 2, 3, 4, 5, 1000],
        "col2": [1, 2, 3, 2, 1, 4]
    }
)

so = Outline(data)
so.delete_outline_by_mean("col1")
# Out:
# [1, 2, 3, 4, 5]
