# %% [markdown]
# <a href="https://colab.research.google.com/github/V9502996099/ML/blob/main/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Airplane_Crashes_and_Fatalities_Since_1908.csv")
df
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
#Первые 5 значений
df[:3]
df.head(3)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
#
#                Operator Flight #          Route              Type  \
# 0  Military - U.S. Army      NaN  Demonstration  Wright Flyer III
# 1  Military - U.S. Navy      NaN    Test flight         Dirigible
# 2               Private        -            NaN  Curtiss seaplane
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...

# %%
#Последние 5 значений
df[len(df)-5:len(df)]
df.tail()
# Out:
#             Date   Time                                           Location  \
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# ...

# %%
#Статистику
df.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**
#
#        Aboard 	  Fatalities   Ground
#
# mean 	27.554518 	20.068303 	1.608845
# 2.   **Ответ 2.**
#
#        Aboard 	Fatalities 	Ground
#
# min 	0.000000 	0.000000 	0.000000
#
# max 	644.000000 	583.000000 	2750.000000

# %%
df.mean()
# Out:
# <ipython-input-49-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Aboard        27.554518
# Fatalities    20.068303
# Ground         1.608845
# dtype: float64

# %%
df.min()
# Out:
# <ipython-input-50-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Date          01/01/1966
# Aboard               0.0
# Fatalities           0.0
# Ground               0.0
# dtype: object

# %%
df.max()
# Out:
# <ipython-input-51-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Date          12/31/1997
# Aboard             644.0
# Fatalities         583.0
# Ground            2750.0
# dtype: object

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
"""
 #   Column        Non-Null Count  Dtype
---  ------        --------------  -----
 0   Date          5268 non-null   object
 1   Time          3049 non-null   object
 2   Location      5248 non-null   object
 3   Operator      5250 non-null   object
 4   Flight #      1069 non-null   object
 5   Route         3562 non-null   object
 6   Type          5241 non-null   object
 7   Registration  4933 non-null   object
 8   cn/In         4040 non-null   object
 9   Aboard        5246 non-null   float64
 10  Fatalities    5256 non-null   float64
 11  Ground        5246 non-null   float64
 12  Summary       4878 non-null   object

Место для вашего кода
"""
df.Location = df.Location.astype("category")
#Вывести типы колонок тут
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   category
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: category(1), float64(3), object(9)
# memory usage: 666.9+ KB

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?
#
# Location - категориальные
# Fatalities - численные

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[df["Aboard"] < 2]
# Out:
#             Date   Time                                      Location  \
# 2     08/06/1913    NaN            Victoria, British Columbia, Canada
# 21    12/16/1918    NaN                         Elizabeth, New Jersey
# 22    05/25/1919    NaN                               Cleveland, Ohio
# 23    07/19/1919    NaN                         Dix Run, Pennsylvania
# 24    10/02/1919    NaN                            Newcastle, England
# ...          ...    ...                                           ...
# 5185  01/14/2008  05:08                              Off Lihu, Hawaii
# 5195  04/09/2008  23:27                           Bundeena, Australia
# 5202  05/23/2008  01:25                             Billings, Montana
# 5210  06/18/2008  10:03                        Hyannis, Massachusetts
# 5266  06/07/2009  08:30  Near Port Hope Simpson, Newfoundland, Canada
#
#                            Operator Flight #  \
# 2                           Private        -
# ...

# %%
#Фильтр колонки 2
df[df["Ground"] >= 1.0]
# Out:
#             Date   Time                   Location  \
# 55    08/24/1921  17:40      River Humber, England
# 58    01/14/1922    NaN              Paris, France
# 296   03/25/1933  20:07        Hayward, California
# 356   05/18/1935  00:45        Near Moscow, Russia
# 433   05/06/1937  19:25      Lakehurst, New Jersey
# ...          ...    ...                        ...
# 5206  05/30/2008  09:40      Tegucigalpa, Honduras
# 5217  07/07/2008  03:50      Near Bogota, Colombia
# 5236  11/04/2008  18:40        Mexico City, Mexico
# 5248  02/12/2009  22:17  Clarence Center, New York
# 5263  05/20/2009  06:30     Near Madiun, Indonesia
#
#                                Operator Flight #  \
# 55       Military - Royal Airship Works      NaN
# 58               Handley Page Transport      NaN
# 296                     Varney Airlines      NaN
# 356                  Gor'ky Eskadril'ya      NaN
# 433          Deutsche Zeppelin Reederei   LZ 129
# ...

# %%
#Фильтр колонки 3
df[df["Fatalities"] == 0.0]
# Out:
#             Date   Time                                      Location  \
# 108   10/21/1926  13:15                               English Channel
# 387   03/05/1936    NaN                            Near Tengya, China
# 889   10/08/1947  07:55                           Near El Paso, Texas
# 897   11/11/1947    NaN                            Gallup, New Mexico
# 1265  05/25/1953  15:30                        Amsterdam, Netherlands
# 1359  01/19/1955  16:25                              Des Moines, Iowa
# 1440  09/09/1956    NaN                        Bartlesville, Oklahoma
# 1443  10/16/1956  06:15                          Over the PacifiOcean
# 1610  06/30/1959  10:35         Ishikawa City, Ryukyu Island, Okinawa
# 1837  02/28/1963  21:29                         Boston, Massachusetts
# 1868  08/21/1963  12:15                       Near Leningrad , Russia
# 1885  12/17/1963  23:41                       Los Angeles, California
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby(["Location"]).count()
# Out:
#                                           Date  Time  Operator  Flight #  \
# Location
# 1,200 miles off Dakar, AtlantiOcean          1     0         1         0
# 100 miles SW of Kuujjuaq, Quebec, Canada     1     1         1         1
# 110 miles SW of Sochi, Russia                1     1         1         1
# 200 miles NE of Derby, Australia             1     1         1         0
# 25 nm off Agrigento, Italy                   1     1         1         1
# ...                                        ...   ...       ...       ...
# Zheng Zou AB, China                          1     0         1         0
# Zifta, Egypt                                 1     1         1         0
# Zurich, Switzerland                          6     3         6         2
# Zwingle, Iowa                                1     1         1         1
# near Orillia, Ontario, Canada                1     1         1         0
#
#                                           Route  Type  Registration  cn/In  \
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
